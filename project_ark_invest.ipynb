# %% [markdown]
# # Analyzing Portfolio Risk and Return
#
# In this Challenge, you'll assume the role of a quantitative analyst for a FinTech investing platform. This platform aims to offer clients a one-stop online investment solution for their retirement portfolios that’s both inexpensive and high quality. (Think about [Wealthfront](https://www.wealthfront.com/) or [Betterment](https://www.betterment.com/)). To keep the costs low, the firm uses algorithms to build each client's portfolio. The algorithms choose from various investment styles and options.
#
# You've been tasked with evaluating four new investment options for inclusion in the client portfolios. Legendary fund and hedge-fund managers run all four selections. (People sometimes refer to these managers as **whales**, because of the large amount of money that they manage). You’ll need to determine the fund with the most investment potential based on key risk-management metrics: the daily returns, standard deviations, Sharpe ratios, and betas.
#
# ## Instructions
#
# ### Import the Data
#
# Use the ``project_ark_invest.ipynb`` file to complete the following steps:
#
# 1. Import the required libraries and dependencies.
#
# 2. Use the ALPACA_API_KEY and ALPACA_SECRET_KEY to read the five ark invest ETF's ( ARKK, ARKQ, ARKW, ARKG, ARKF) data's  into a Pandas DataFrame.  Review the first five rows of the DataFrame by using the `head` function.
#
# 3. Use the Pandas `pct_change` function together with `dropna` to create the daily returns DataFrame. Base this DataFrame on the NAV prices of the four portfolios and on the closing price of the S&P 500 Index. Review the first five rows of the daily returns DataFrame.
#
# ### Analyze the Performance
#
# Analyze the data to determine if any of the portfolios outperform the broader stock market, which the S&P 500 represents. To do so, complete the following steps:
#
# 1. Use the default Pandas `plot` function to visualize the daily return data of the four fund portfolios and the S&P 500. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. Use the Pandas `cumprod` function to calculate the cumulative returns for the four fund portfolios and the S&P 500. Review the last five rows of the cumulative returns DataFrame by using the Pandas `tail` function.
#
# 3. Use the default Pandas `plot` to visualize the cumulative return values for the four funds and the S&P 500 over time. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Answer the following question: Based on the cumulative return data and the visualization, do any of the four fund portfolios outperform the S&P 500 Index?
#
# ### Analyze the Volatility
#
# Analyze the volatility of each of the four fund portfolios and of the S&P 500 Index by using box plots. To do so, complete the following steps:
#
# 1. Use the Pandas `plot` function and the `kind="box"` parameter to visualize the daily return data for each of the four portfolios and for the S&P 500 in a box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. Use the Pandas `drop` function to create a new DataFrame that contains the data for just the four fund portfolios by dropping the S&P 500 column. Visualize the daily return data for just the four fund portfolios by using another box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
#     > **Hint** Save this new DataFrame&mdash;the one that contains the data for just the four fund portfolios. You’ll use it throughout the analysis.
#
# 3. Answer the following question: Based on the box plot visualization of just the four fund portfolios, which fund was the most volatile (with the greatest spread) and which was the least volatile (with the smallest spread)?
#
# ### Analyze the Risk
#
# Evaluate the risk profile of each portfolio by using the standard deviation and the beta. To do so, complete the following steps:
#
# 1. Use the Pandas `std` function to calculate the standard deviation for each of the four portfolios and for the S&P 500. Review the standard deviation calculations, sorted from smallest to largest.
#
# 2. Calculate the annualized standard deviation for each of the four portfolios and for the S&P 500. To do that, multiply the standard deviation by the square root of the number of trading days. Use 252 for that number.
#
# 3. Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of the four fund portfolios and of the S&P 500 index. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of only the four fund portfolios. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 5. Answer the following three questions:
#
# * Based on the annualized standard deviation, which portfolios pose more risk than the S&P 500?
#
# * Based on the rolling metrics, does the risk of each portfolio increase at the same time that the risk of the S&P 500 increases?
#
# * Based on the rolling standard deviations of only the four fund portfolios, which portfolio poses the most risk? Does this change over time?
#
# ### Analyze the Risk-Return Profile
#
# To determine the overall risk of an asset or portfolio, quantitative analysts and investment managers consider not only its risk metrics but also its risk-return profile. After all, if you have two portfolios that each offer a 10% return but one has less risk, you’d probably invest in the smaller-risk portfolio. For this reason, you need to consider the Sharpe ratios for each portfolio. To do so, complete the following steps:
#
# 1. Use the daily return DataFrame to calculate the annualized average return data for the four fund portfolios and for the S&P 500. Use 252 for the number of trading days. Review the annualized average returns, sorted from lowest to highest.
#
# 2. Calculate the Sharpe ratios for the four fund portfolios and for the S&P 500. To do that, divide the annualized average return by the annualized standard deviation for each. Review the resulting Sharpe ratios, sorted from lowest to highest.
#
# 3. Visualize the Sharpe ratios for the four funds and for the S&P 500 in a bar chart. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Answer the following question: Which of the four portfolios offers the best risk-return profile? Which offers the worst?
#
# #### Diversify the Portfolio
#
# Your analysis is nearing completion. Now, you need to evaluate how the portfolios react relative to the broader market. Based on your analysis so far, choose two portfolios that you’re most likely to recommend as investment options. To start your analysis, complete the following step:
#
# * Use the Pandas `var` function to calculate the variance of the S&P 500 by using a 60-day rolling window. Visualize the last five rows of the variance of the S&P 500.
#
# Next, for each of the two portfolios that you chose, complete the following steps:
#
# 1. Using the 60-day rolling window, the daily return data, and the S&P 500 returns, calculate the covariance. Review the last five rows of the covariance of the portfolio.
#
# 2. Calculate the beta of the portfolio. To do that, divide the covariance of the portfolio by the variance of the S&P 500.
#
# 3. Use the Pandas `mean` function to calculate the average value of the 60-day rolling beta of the portfolio.
#
# 4. Plot the 60-day rolling beta. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# Finally, answer the following two questions:
#
# * Which of the two portfolios seem more sensitive to movements in the S&P 500?
#
# * Which of the two portfolios do you recommend for inclusion in your firm’s suite of fund offerings?

# %% [markdown]
# # Analyzing Portfolio Risk and Return
#
# In this Challenge, you'll assume the role of a quantitative analyst for a FinTech investing platform. This platform aims to offer clients a one-stop online investment solution for their retirement portfolios that’s both inexpensive and high quality. (Think about [Wealthfront](https://www.wealthfront.com/) or [Betterment](https://www.betterment.com/)). To keep the costs low, the firm uses algorithms to build each client's portfolio. The algorithms choose from various investment styles and options.
#
# You've been tasked with evaluating four new investment options for inclusion in the client portfolios. Legendary fund and hedge-fund managers run all four selections. (People sometimes refer to these managers as **whales**, because of the large amount of money that they manage). You’ll need to determine the fund with the most investment potential based on key risk-management metrics: the daily returns, standard deviations, Sharpe ratios, and betas.
#
# ## Instructions
#
# ### Import the Data
#
# Use the ``risk_return_analysis.ipynb`` file to complete the following steps:
#
# 1. Import the required libraries and dependencies.
#
# 2. Use the `read_csv` function and the `Path` module to read the `whale_navs.csv` file into a Pandas DataFrame. Be sure to create a `DateTimeIndex`. Review the first five rows of the DataFrame by using the `head` function.
#
# 3. Use the Pandas `pct_change` function together with `dropna` to create the daily returns DataFrame. Base this DataFrame on the NAV prices of the four portfolios and on the closing price of the S&P 500 Index. Review the first five rows of the daily returns DataFrame.
#
# ### Analyze the Performance
#
# Analyze the data to determine if any of the portfolios outperform the broader stock market, which the S&P 500 represents. To do so, complete the following steps:
#
# 1. Use the default Pandas `plot` function to visualize the daily return data of the four fund portfolios and the S&P 500. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. Use the Pandas `cumprod` function to calculate the cumulative returns for the four fund portfolios and the S&P 500. Review the last five rows of the cumulative returns DataFrame by using the Pandas `tail` function.
#
# 3. Use the default Pandas `plot` to visualize the cumulative return values for the four funds and the S&P 500 over time. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Answer the following question: Based on the cumulative return data and the visualization, do any of the four fund portfolios outperform the S&P 500 Index?
#
# ### Analyze the Volatility
#
# Analyze the volatility of each of the four fund portfolios and of the S&P 500 Index by using box plots. To do so, complete the following steps:
#
# 1. Use the Pandas `plot` function and the `kind="box"` parameter to visualize the daily return data for each of the four portfolios and for the S&P 500 in a box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. Use the Pandas `drop` function to create a new DataFrame that contains the data for just the four fund portfolios by dropping the S&P 500 column. Visualize the daily return data for just the four fund portfolios by using another box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
#     > **Hint** Save this new DataFrame&mdash;the one that contains the data for just the four fund portfolios. You’ll use it throughout the analysis.
#
# 3. Answer the following question: Based on the box plot visualization of just the four fund portfolios, which fund was the most volatile (with the greatest spread) and which was the least volatile (with the smallest spread)?
#
# ### Analyze the Risk
#
# Evaluate the risk profile of each portfolio by using the standard deviation and the beta. To do so, complete the following steps:
#
# 1. Use the Pandas `std` function to calculate the standard deviation for each of the four portfolios and for the S&P 500. Review the standard deviation calculations, sorted from smallest to largest.
#
# 2. Calculate the annualized standard deviation for each of the four portfolios and for the S&P 500. To do that, multiply the standard deviation by the square root of the number of trading days. Use 252 for that number.
#
# 3. Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of the four fund portfolios and of the S&P 500 index. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of only the four fund portfolios. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 5. Answer the following three questions:
#
# * Based on the annualized standard deviation, which portfolios pose more risk than the S&P 500?
#
# * Based on the rolling metrics, does the risk of each portfolio increase at the same time that the risk of the S&P 500 increases?
#
# * Based on the rolling standard deviations of only the four fund portfolios, which portfolio poses the most risk? Does this change over time?
#
# ### Analyze the Risk-Return Profile
#
# To determine the overall risk of an asset or portfolio, quantitative analysts and investment managers consider not only its risk metrics but also its risk-return profile. After all, if you have two portfolios that each offer a 10% return but one has less risk, you’d probably invest in the smaller-risk portfolio. For this reason, you need to consider the Sharpe ratios for each portfolio. To do so, complete the following steps:
#
# 1. Use the daily return DataFrame to calculate the annualized average return data for the four fund portfolios and for the S&P 500. Use 252 for the number of trading days. Review the annualized average returns, sorted from lowest to highest.
#
# 2. Calculate the Sharpe ratios for the four fund portfolios and for the S&P 500. To do that, divide the annualized average return by the annualized standard deviation for each. Review the resulting Sharpe ratios, sorted from lowest to highest.
#
# 3. Visualize the Sharpe ratios for the four funds and for the S&P 500 in a bar chart. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Answer the following question: Which of the four portfolios offers the best risk-return profile? Which offers the worst?
#
# #### Diversify the Portfolio
#
# Your analysis is nearing completion. Now, you need to evaluate how the portfolios react relative to the broader market. Based on your analysis so far, choose two portfolios that you’re most likely to recommend as investment options. To start your analysis, complete the following step:
#
# * Use the Pandas `var` function to calculate the variance of the S&P 500 by using a 60-day rolling window. Visualize the last five rows of the variance of the S&P 500.
#
# Next, for each of the two portfolios that you chose, complete the following steps:
#
# 1. Using the 60-day rolling window, the daily return data, and the S&P 500 returns, calculate the covariance. Review the last five rows of the covariance of the portfolio.
#
# 2. Calculate the beta of the portfolio. To do that, divide the covariance of the portfolio by the variance of the S&P 500.
#
# 3. Use the Pandas `mean` function to calculate the average value of the 60-day rolling beta of the portfolio.
#
# 4. Plot the 60-day rolling beta. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# Finally, answer the following two questions:
#
# * Which of the two portfolios seem more sensitive to movements in the S&P 500?
#
# * Which of the two portfolios do you recommend for inclusion in your firm’s suite of fund offerings?

# %% [markdown]
# ## Import Data
#
# ### Importing the required libraries and dependencies

# %%
from pathlib import Path
import numpy as np
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation
import hvplot.pandas

# %matplotlib inline

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Analyze the Performance
#
# Analyze the data to determine if any of the portfolios outperform the broader stock market, which the S&P 500 represents. To do so, complete the following steps:
#
# 1. Use the default Pandas `plot` function to visualize the daily return data of the four fund portfolios and the S&P 500. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. Use the Pandas `cumprod` function to calculate the cumulative returns for the four fund portfolios and the S&P 500. Review the last five rows of the cumulative returns DataFrame by using the Pandas `tail` function.
#
# 3. Use the default Pandas `plot` to visualize the cumulative return values for the four funds and the S&P 500 over time. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. Answer the following question: Based on the cumulative return data and the visualization, do any of the four fund portfolios outperform the S&P 500 Index?

# %% [markdown]
# ### Set the variables for the Alpaca API and secret keys. Import, slice and clean datas and set it to the dataframe.

# %%
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
alpaca_api_key 
alpaca_secret_key 

alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
tickers = ["ARKK", "ARKQ", "ARKW", "ARKG", "ARKF", "SPY"]
timeframe = "1D"

start_date = pd.Timestamp("2019-01-01", hour=None,minute=None, second=None, tz="America/Chicago").isoformat()
end_date = pd.Timestamp("2022-02-14", hour=None,minute=None, second=None, tz="America/Chicago").isoformat()

# %%
ark_df = alpaca.get_barset(
    tickers,
    timeframe, 
    start=start_date,
    end=end_date,
    limit=1000
).df

# Review the first 5 rows of the Alpaca DataFrame
# YOUR CODE HERE
display(ark_df.head())
display(ark_df.tail())
# Out:
# /var/folders/w0/qbng3fc92pqdfc6992jvjq080000gn/T/ipykernel_2306/2336836819.py:1: DeprecatedWarning: get_barset is deprecated as of v1.0.0. Use get_bars instead
#   ark_df = alpaca.get_barset(
#                           ARKF                         ARKG                    \
#                           open high low close volume   open     high      low
# time
# 2019-01-02 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  23.69  24.4599  23.4522
# 2019-01-03 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  24.50  24.6699  24.0883
# 2019-01-04 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  24.60  25.8402  24.6000
# 2019-01-07 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  26.56  27.5199  26.3490
# 2019-01-08 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  27.70  27.7899  26.5700
#
#                                               ...   ARKW                   \
#                              close    volume  ...   open    high      low
# time                                          ...
# ...

# %%
ark_df = ark_df.dropna()
ark_df.head()
# Out:
#                             ARKF                                       ARKG  \
#                             open     high     low    close    volume   open
# time
# 2019-02-04 00:00:00-05:00  20.16  20.4100  20.157  20.3552   57308.0  28.30
# 2019-02-05 00:00:00-05:00  20.48  20.6100  20.430  20.5499  112747.0  28.70
# 2019-02-06 00:00:00-05:00  20.52  20.5336  20.310  20.4800   45401.0  28.40
# 2019-02-07 00:00:00-05:00  20.29  20.3200  20.000  20.1699   59265.0  28.07
# 2019-02-08 00:00:00-05:00  20.00  20.2100  19.950  20.1799   20976.0  27.29
#
#                                                               ...   ARKW  \
#                               high    low    close    volume  ...   open
# time                                                          ...
# 2019-02-04 00:00:00-05:00  28.5700  28.05  28.5500  367182.0  ...  49.50
# 2019-02-05 00:00:00-05:00  29.0000  28.21  28.3309   69300.0  ...  50.45
# ...

# %%
ark_df.columns = ['_'.join(x) for x in ark_df.columns]

# %%
ark_df_close = ark_df.loc[:, ark_df.columns.str.contains("_close")].rename_axis("Date")
ark_df_close.head()
# Out:
#                            ARKF_close  ARKG_close  ARKK_close  ARKQ_close  \
# Date
# 2019-02-04 00:00:00-05:00     20.3552     28.5500       43.79      33.667
# 2019-02-05 00:00:00-05:00     20.5499     28.3309       43.91      34.130
# 2019-02-06 00:00:00-05:00     20.4800     28.4100       43.98      34.210
# 2019-02-07 00:00:00-05:00     20.1699     27.6100       42.50      33.110
# 2019-02-08 00:00:00-05:00     20.1799     27.7500       42.93      33.280
#
#                            ARKW_close  SPY_close
# Date
# 2019-02-04 00:00:00-05:00     50.2661     271.78
# 2019-02-05 00:00:00-05:00     50.6800     273.13
# 2019-02-06 00:00:00-05:00     50.4200     272.70
# 2019-02-07 00:00:00-05:00     49.2500     269.97
# 2019-02-08 00:00:00-05:00     49.5600     270.08

# %% [markdown]
# ## Use the Pandas pct_change function together with dropna to create the daily returns DataFrame.

# %%
ark_df_daily_return = ark_df_close.pct_change().dropna()
ark_df_daily_return
# Out:
#                            ARKF_close  ARKG_close  ARKK_close  ARKQ_close  \
# Date
# 2019-02-05 00:00:00-05:00    0.009565   -0.007674    0.002740    0.013752
# 2019-02-06 00:00:00-05:00   -0.003401    0.002792    0.001594    0.002344
# 2019-02-07 00:00:00-05:00   -0.015142   -0.028159   -0.033652   -0.032154
# 2019-02-08 00:00:00-05:00    0.000496    0.005071    0.010118    0.005134
# 2019-02-11 00:00:00-05:00    0.005055    0.013333    0.010780    0.010222
# ...                               ...         ...         ...         ...
# 2022-02-08 00:00:00-05:00    0.010901   -0.010498   -0.001104    0.021937
# 2022-02-09 00:00:00-05:00    0.058674    0.053873    0.050283    0.025094
# 2022-02-10 00:00:00-05:00   -0.025165   -0.028834   -0.028804   -0.024775
# 2022-02-11 00:00:00-05:00   -0.026736   -0.022947   -0.027356   -0.017088
# 2022-02-14 00:00:00-05:00   -0.003473   -0.018953   -0.006266   -0.001538
#
#                            ARKW_close  SPY_close
# Date
# ...

# %% [markdown]
# # Quantitative Analysis
# ## Analyze the Performance
# ### Analyze the data to determine if any of the ETF's outperform the broader stock market, which the S&P 500 represents.

# %%
ark_df_daily_return = ark_df_daily_return.hvplot( 
                           hover_color = 'Black', 
                           title="Daily Return- Ark Invest ETFs", 
                           ylabel="Percentage",
                           frame_width = 800,
                           frame_height = 500
                          
                          )

# %%
ark_df_daily_return
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
hvplot.save(ark_df_daily_return, 'ark_df_daily_return.html') # saving HTML files to link interactive plots for presentation

# %% [markdown]
# ### Use the Pandas cumprod function to calculate the cumulative returns for the five ETF's  and SPY. Review the last five rows of the cumulative returns DataFrame by using the Pandas tail function.¶

# %%
ark_df_cumulative_returns = (1 + ark_df_daily_return).cumprod()
ark_df_cumulative_returns.tail()
# Out:
#                            ARKF_close  ARKG_close  ARKK_close  ARKQ_close  \
# Date
# 2022-02-08 00:00:00-05:00    1.548990    1.700175    1.653117    1.964832
# 2022-02-09 00:00:00-05:00    1.639876    1.791769    1.736241    2.014138
# 2022-02-10 00:00:00-05:00    1.598609    1.740105    1.686230    1.964238
# 2022-02-11 00:00:00-05:00    1.555868    1.700175    1.640100    1.930674
# 2022-02-14 00:00:00-05:00    1.550464    1.667951    1.629824    1.927704
#
#                            ARKW_close  SPY_close
# Date
# 2022-02-08 00:00:00-05:00    1.857713   1.659026
# 2022-02-09 00:00:00-05:00    1.943855   1.683384
# 2022-02-10 00:00:00-05:00    1.890936   1.653433
# 2022-02-11 00:00:00-05:00    1.834636   1.620686
# 2022-02-14 00:00:00-05:00    1.829663   1.615461

# %%
ark_df_cumulative_returns.hvplot(title="Cumulative Return-Whale Navs", 
                                 ylabel="Percentage",
                                 hover_color = 'Black',
                                 frame_width = 800,
                                 frame_height = 500
                                  )
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %% [markdown]
# ### Based on the cumulative return data and the visualization, all five ETF's outperformed SPY starting from April 2020, they all peaked in January 2021 and in January 2022 they're all back to the SPY level.

# %% [markdown]
# # Analyze the Volatility
# ## Analyze the volatility of each of the five funds and of the S&P 500 by using box plots.

# %%
ark_df_daily_return.hvplot(kind="box",
                           frame_width = 800,
                           frame_height = 500,
                           title="Individual Daily Return", 
                           ylabel= "percentage")
# Out:
# :BoxWhisker   [Variable]   (value)

# %% [markdown]
# ### ***Based on the box plot visualization of the five ETF's and SPY, ARKK fund was the most volatile (with the greatest spread) and ARKQ fund was the least volatile (with the smallest spread).***

# %% [markdown]
# # Analyze the Risk¶

# %% [markdown]
# #### Evaluate the risk profile of each portfolio by using the standard deviation and the beta.
# #### Step 1: Use the Pandas std function to calculate the standard deviation for each of the five ETF's and for the SPY. Review the standard deviation calculations, sorted from smallest to largest.¶

# %%
ark_df_daily_return.std().sort_values()
# Out:
# SPY_close     0.014098
# ARKQ_close    0.020070
# ARKF_close    0.021175
# ARKW_close    0.023696
# ARKK_close    0.025584
# ARKG_close    0.026620
# dtype: float64

# %% [markdown]
# #### Step 2: Calculate the annualized standard deviation for each of the five ETF's  and for the SPY. To do that, multiply the standard deviation by the square root of the number of trading days. Use 252 for that number.

# %%
ark_df_annual_std_dev = ark_df_daily_return.std().sort_values()*np.sqrt(252)
ark_df_annual_std_dev
# Out:
# SPY_close     0.223806
# ARKQ_close    0.318604
# ARKF_close    0.336148
# ARKW_close    0.376166
# ARKK_close    0.406131
# ARKG_close    0.422577
# dtype: float64

# %% [markdown]
# #### Step 3: Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of the four fund portfolios and of the S&P 500 index. Be sure to include the title parameter, and adjust the figure size if necessary.¶

# %%
ark_df_21 = ark_df_daily_return.rolling(window=21,).std()
ark_df_21.hvplot(frame_width = 800,
                 frame_height = 500,
                 hover_color = 'Black',
                 xlabel = 'Date',
                 ylabel = 'Standard Deviation',
                 title="21-Day Rolling Standard Deviation")
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %% [markdown]
# ##### Question 1 Based on the annualized standard deviation, which portfolios pose more risk than the S&P 500?
#
# #### ***All of the five ETF's poses more risk than the SPY.***
#
# ##### Question 2 Based on the rolling metrics, does the risk of each portfolio increase at the same time that the risk of the S&P 500 increases?
#
# #### ***Yes, all five ETF's  follow the SPY, the correlation between the 5 ETF's and the SPY is very ovious as you see from the chart.***
#
# ##### Question 3 Based on the rolling standard deviations of only the five fund portfolios, which portfolio poses the most risk? Does this change over time?
#
# #### ***ARKK poses a riskier investment, it topped thrice in three-year chart shown above.***

# %% [markdown]
# # Analyze the Risk-Return Profile
# #### To determine the overall risk of an asset or portfolio, quantitative analysts and investment managers consider not only its risk metrics but also its risk-return profile. After all, if you have two portfolios that each offer a 10% return but one has less risk, you’d probably invest in the smaller-risk portfolio. For this reason, you need to consider the Sharpe ratios for each portfolio.

# %% [markdown]
# ##### Step 1: Use the daily return DataFrame to calculate the annualized average return data for the five ETF's and for the S&P 500. Use 252 for the number of trading days. Review the annualized average returns, sorted from lowest to highest.

# %%
ark_df_annual_return = ark_df_daily_return.mean()*252
ark_df_annual_return.sort_values()
# Out:
# SPY_close     0.183872
# ARKF_close    0.201922
# ARKK_close    0.244759
# ARKG_close    0.258829
# ARKQ_close    0.268073
# ARKW_close    0.271251
# dtype: float64

# %% [markdown]
# ##### Step 2: Calculate the Sharpe ratios for the five ETF's and for the SPY. To do that, divide the annualized average return by the annualized standard deviation for each. Review the resulting Sharpe ratios, sorted from lowest to highest.¶

# %%
sharpe_ratios_ark_df = ark_df_annual_return / ark_df_annual_std_dev
sharpe_ratios_ark_df.sort_values()
# Out:
# ARKF_close    0.600694
# ARKK_close    0.602660
# ARKG_close    0.612502
# ARKW_close    0.721093
# SPY_close     0.821570
# ARKQ_close    0.841400
# dtype: float64

# %% [markdown]
# ##### Step 3: Visualize the Sharpe ratios for the five ETF's and for the SPY in a bar chart.

# %%
sharpe_ratios_ark_df.hvplot.bar(frame_width= 800,
                                frame_height = 500,
                                hover_color = 'Black',
                                rot = 0,
                                xlabel = "ETFs",
                                ylabel = "Sharpe Ratio",
                                title="Sharpe Ratios")
# Out:
# :Bars   [index]   (0)

# %% [markdown]
# ##### Question Which of the four portfolios offers the best risk-return profile? Which offers the worst?
#
# ##### ***ARKQ has the best risk-return profile, while ARKF has the worse.***

# %% [markdown]
# # Diversifying the Portfolio¶

# %% [markdown]
# ### Calculate the variance of the S&P 500 by using a 60-day rolling window and visualize the last five rows.

# %%
spy_60_var = ark_df_daily_return.loc[:, "SPY_close"].rolling(window=60).var()                                                  
spy_60_var.tail()
# Out:
# Date
# 2022-02-08 00:00:00-05:00    0.000122
# 2022-02-09 00:00:00-05:00    0.000125
# 2022-02-10 00:00:00-05:00    0.000130
# 2022-02-11 00:00:00-05:00    0.000135
# 2022-02-14 00:00:00-05:00    0.000136
# Name: SPY_close, dtype: float64

# %% [markdown]
# ##### ARKF - Step 1: Calculate the covariance of ARKF by using the 60-day rolling window, the daily return data, and the SPY_close returns, . Review the last five rows of the covariance of ARKF.¶

# %%
arkf_60_cov = ark_df_daily_return["ARKF_close"].rolling(window=60).cov( ark_df_daily_return["SPY_close"])
arkf_60_cov.tail()
# Out:
# Date
# 2022-02-08 00:00:00-05:00    0.000242
# 2022-02-09 00:00:00-05:00    0.000255
# 2022-02-10 00:00:00-05:00    0.000260
# 2022-02-11 00:00:00-05:00    0.000265
# 2022-02-14 00:00:00-05:00    0.000265
# dtype: float64

# %% [markdown]
# ##### ARKF  - Step 2: Calculate the Beta of ARKF based on the 60-day rolling covariance. To do that, divide the covariance of ARKF by the variance of the SPY.

# %%
arkf_60_beta = arkf_60_cov / spy_60_var
arkf_60_beta.fillna(0)
# Out:
# Date
# 2019-02-05 00:00:00-05:00    0.000000
# 2019-02-06 00:00:00-05:00    0.000000
# 2019-02-07 00:00:00-05:00    0.000000
# 2019-02-08 00:00:00-05:00    0.000000
# 2019-02-11 00:00:00-05:00    0.000000
#                                ...
# 2022-02-08 00:00:00-05:00    1.984438
# 2022-02-09 00:00:00-05:00    2.044696
# 2022-02-10 00:00:00-05:00    2.004156
# 2022-02-11 00:00:00-05:00    1.958124
# 2022-02-14 00:00:00-05:00    1.953424
# Length: 762, dtype: float64

# %% [markdown]
# ##### ARKF  - Step 3: Use the Pandas mean function to calculate the average value of the 60-day rolling beta of ARKF.¶

# %%
arkf_60_beta_ave = arkf_60_beta.mean()
arkf_60_beta_ave
print(f"The Average value of the 60-day rolling beta for ARKF is {arkf_60_beta_ave: .2f}")
# Out:
# The Average value of the 60-day rolling beta for ARKF is  1.27

# %%
arkf_60_beta.hvplot(frame_width = 800,
                  frame_height = 500,
                  hover_color = 'Yellow',
                  xlabel = 'Date',
                  ylabel = 'Beta',
                  title="60-day Rolling Beta for ARKF")
# Out:
# :Curve   [Date]   (0)

# %% [markdown]
# ## Repeat Steps 1-3 for the remainder of the ETFs.

# %%
arkg_60_cov = ark_df_daily_return["ARKG_close"].rolling(window=60).cov( ark_df_daily_return["SPY_close"])
arkg_60_cov.tail()
# Out:
# Date
# 2022-02-08 00:00:00-05:00    0.000193
# 2022-02-09 00:00:00-05:00    0.000208
# 2022-02-10 00:00:00-05:00    0.000215
# 2022-02-11 00:00:00-05:00    0.000218
# 2022-02-14 00:00:00-05:00    0.000218
# dtype: float64

# %%
arkg_60_beta = arkg_60_cov / spy_60_var
arkg_60_beta.fillna(0)
# Out:
# Date
# 2019-02-05 00:00:00-05:00    0.000000
# 2019-02-06 00:00:00-05:00    0.000000
# 2019-02-07 00:00:00-05:00    0.000000
# 2019-02-08 00:00:00-05:00    0.000000
# 2019-02-11 00:00:00-05:00    0.000000
#                                ...
# 2022-02-08 00:00:00-05:00    1.585587
# 2022-02-09 00:00:00-05:00    1.668150
# 2022-02-10 00:00:00-05:00    1.657161
# 2022-02-11 00:00:00-05:00    1.611506
# 2022-02-14 00:00:00-05:00    1.611572
# Length: 762, dtype: float64

# %%
arkg_60_beta_ave = arkg_60_beta.mean()
arkg_60_beta_ave
print(f"The Average value of the 60-day rolling beta for ARKG is {arkg_60_beta_ave: .2f}")
# Out:
# The Average value of the 60-day rolling beta for ARKG is  1.35

# %%
arkg_60_beta.hvplot(frame_width = 800,
                  frame_height = 500,
                  hover_color = 'Yellow',
                  xlabel = 'Date',
                  ylabel = 'Beta',
                  title="60-day Rolling Beta for ARKG")
# Out:
# :Curve   [Date]   (0)

# %%
arkk_60_cov = ark_df_daily_return["ARKK_close"].rolling(window=60).cov( ark_df_daily_return["SPY_close"])
arkk_60_cov.tail()
# Out:
# Date
# 2022-02-08 00:00:00-05:00    0.000221
# 2022-02-09 00:00:00-05:00    0.000234
# 2022-02-10 00:00:00-05:00    0.000240
# 2022-02-11 00:00:00-05:00    0.000245
# 2022-02-14 00:00:00-05:00    0.000245
# dtype: float64

# %%
arkk_60_beta = arkk_60_cov / spy_60_var
arkk_60_beta.fillna(0)
# Out:
# Date
# 2019-02-05 00:00:00-05:00    0.000000
# 2019-02-06 00:00:00-05:00    0.000000
# 2019-02-07 00:00:00-05:00    0.000000
# 2019-02-08 00:00:00-05:00    0.000000
# 2019-02-11 00:00:00-05:00    0.000000
#                                ...
# 2022-02-08 00:00:00-05:00    1.817847
# 2022-02-09 00:00:00-05:00    1.875403
# 2022-02-10 00:00:00-05:00    1.851470
# 2022-02-11 00:00:00-05:00    1.808459
# 2022-02-14 00:00:00-05:00    1.805656
# Length: 762, dtype: float64

# %%
arkk_60_beta_ave = arkk_60_beta.mean()
arkk_60_beta_ave
print(f"The Average value of the 60-day rolling beta for ARKK is {arkk_60_beta_ave: .2f}")
# Out:
# The Average value of the 60-day rolling beta for ARKK is  1.45

# %%
arkk_60_beta.hvplot(frame_width = 800,
                  frame_height = 500,
                  hover_color = 'Yellow',
                  xlabel = 'Date',
                  ylabel = 'Beta',
                  title="60-day Rolling Beta for ARKK")
# Out:
# :Curve   [Date]   (0)

# %%
arkq_60_cov = ark_df_daily_return["ARKQ_close"].rolling(window=60).cov( ark_df_daily_return["SPY_close"])
arkq_60_cov.tail()
# Out:
# Date
# 2022-02-08 00:00:00-05:00    0.000175
# 2022-02-09 00:00:00-05:00    0.000181
# 2022-02-10 00:00:00-05:00    0.000187
# 2022-02-11 00:00:00-05:00    0.000190
# 2022-02-14 00:00:00-05:00    0.000190
# dtype: float64

# %%
arkq_60_beta = arkq_60_cov / spy_60_var
arkq_60_beta.fillna(0)
# Out:
# Date
# 2019-02-05 00:00:00-05:00    0.000000
# 2019-02-06 00:00:00-05:00    0.000000
# 2019-02-07 00:00:00-05:00    0.000000
# 2019-02-08 00:00:00-05:00    0.000000
# 2019-02-11 00:00:00-05:00    0.000000
#                                ...
# 2022-02-08 00:00:00-05:00    1.434935
# 2022-02-09 00:00:00-05:00    1.453114
# 2022-02-10 00:00:00-05:00    1.442457
# 2022-02-11 00:00:00-05:00    1.402399
# 2022-02-14 00:00:00-05:00    1.400255
# Length: 762, dtype: float64

# %%
arkq_60_beta_ave = arkq_60_beta.mean()
arkq_60_beta_ave
print(f"The Average value of the 60-day rolling beta for ARKQ is {arkq_60_beta_ave: .2f}")
# Out:
# The Average value of the 60-day rolling beta for ARKQ is  1.34

# %%
arkq_60_beta.hvplot(frame_width = 800,
                  frame_height = 500,
                  hover_color = 'Yellow',
                  xlabel = 'Date',
                  ylabel = 'Beta',
                  title="60-day Rolling Beta for ARKQ")
# Out:
# :Curve   [Date]   (0)

# %%
arkw_60_cov = ark_df_daily_return["ARKW_close"].rolling(window=60).cov( ark_df_daily_return["SPY_close"])
arkw_60_cov.tail()
# Out:
# Date
# 2022-02-08 00:00:00-05:00    0.000232
# 2022-02-09 00:00:00-05:00    0.000242
# 2022-02-10 00:00:00-05:00    0.000247
# 2022-02-11 00:00:00-05:00    0.000254
# 2022-02-14 00:00:00-05:00    0.000253
# dtype: float64

# %%
arkw_60_beta = arkw_60_cov / spy_60_var
arkw_60_beta.fillna(0)
# Out:
# Date
# 2019-02-05 00:00:00-05:00    0.000000
# 2019-02-06 00:00:00-05:00    0.000000
# 2019-02-07 00:00:00-05:00    0.000000
# 2019-02-08 00:00:00-05:00    0.000000
# 2019-02-11 00:00:00-05:00    0.000000
#                                ...
# 2022-02-08 00:00:00-05:00    1.900025
# 2022-02-09 00:00:00-05:00    1.938921
# 2022-02-10 00:00:00-05:00    1.907341
# 2022-02-11 00:00:00-05:00    1.872613
# 2022-02-14 00:00:00-05:00    1.869828
# Length: 762, dtype: float64

# %%
arkw_60_beta_ave = arkw_60_beta.mean()
arkw_60_beta_ave
print(f"The Average value of the 60-day rolling beta for ARKW is {arkw_60_beta_ave: .2f}")
# Out:
# The Average value of the 60-day rolling beta for ARKW is  1.37

# %%
arkw_60_beta.hvplot(frame_width = 800,
                  frame_height = 500,
                  hover_color = 'Yellow',
                  xlabel = 'Date',
                  ylabel = 'Beta',
                  title="60-day Rolling Beta for ARKW")
# Out:
# :Curve   [Date]   (0)

# %% [markdown]
# ## Creating the Monte Carlo Simulation
#
# ##### Run a Monte Carlo simulation of 500 samples and 30 years for the 15,15,20,20,30,0 portfolio, and then plot the results.The following image shows the overlay line plot resulting from a simulation with these characteristics. However, because a random number generator is used to run each live Monte Carlo simulation, your image will differ slightly from this exact image:

# %%
MC_even_weight = MCSimulation(
    portfolio_data = ark_df,
    weights = [.15,.15,.20,.20,.30,0.00],
    num_simulation = 500,
    num_trading_days = 252*3
)
MC_even_weight.portfolio_data.tail()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w0/qbng3fc92pqdfc6992jvjq080000gn/T/ipykernel_2306/2880390194.py in <module>
# ----> 1 MC_even_weight = MCSimulation(
#       2     portfolio_data = ark_df,
#       3     weights = [.15,.15,.20,.20,.30,0.00],
#       4     num_simulation = 500,
#       5     num_trading_days = 252*3
#
# ~/Desktop/FinTech-Workspace/Module 8 - Project 1/Project_1/MCForecastTools.py in __init__(self, portfolio_data, weights, num_simulation, num_trading_days)
#      59
#      60         # Calculate daily return if not within dataframe
# ---> 61         if not "daily_return" in portfolio_data.columns.get_level_values(1).unique():
#      62             close_df = portfolio_data.xs('close',level=1,axis=1).pct_change()
#      63             tickers = portfolio_data.columns.get_level_values(0).unique()
#
# ...

# %% [markdown]
# #### Run the Monte Carlo simulation to forecast 30 years cumulative returns

# %%
MC_even_weight.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %% [markdown]
# ##### Visualize the 30-year Monte Carlo simulation by creating an ovewrlay line plot

# %%
even_weight_line_plot = MC_even_weight.plot_simulation()
